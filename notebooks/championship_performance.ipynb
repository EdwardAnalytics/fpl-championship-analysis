# %%
# Change directory to level up to import functions
import os
os.chdir('..')

import warnings

# Suppress all warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

from src.analysis.championship_performance import (
    format_dataframe,
    get_top_ranked_players,
    match_and_merge_with_fpl_data,
    process_promotions,
)
from src.data_prep.join_data import (
    load_combine_championship_assists_data,
    load_combine_championship_goals_data,
)
from src.tools.yaml_loader import load_yaml_file

# Load promotion/relegation yaml
file_path = "conf/promoted_teams_by_season.yaml"
promoted_teams_by_season = load_yaml_file(file_path)

# %%
# Goal scorers
season_years = [
    '2015-2016',
    '2016-2017',
    '2017-2018',
    '2018-2019',
    '2019-2020',
    '2020-2021',
    '2021-2022',
    '2022-2023',
    '2023-2024',
]

df_goals = load_combine_championship_goals_data(
    season_years=season_years, export_csv=True
)
df_assists = load_combine_championship_assists_data(
    season_years=season_years, export_csv=True
)

# Filter promoted players
df_goals = process_promotions(df_goals, promoted_teams_by_season)
df_assists = process_promotions(df_assists, promoted_teams_by_season)

# Join with FPL data
fpl_df = pd.read_csv('data/fpl_data/joined/seasons_joined.csv')
df_goals = match_and_merge_with_fpl_data(df=df_goals, fpl_df=fpl_df)
df_assists = match_and_merge_with_fpl_data(df=df_assists, fpl_df=fpl_df)

# Reformat and tidy output
df_goals = format_dataframe(df=df_goals, metric='Goals', export_csv=True)
df_assists = format_dataframe(df=df_assists, metric='Assists', export_csv=True)

# %%
# Preview data
get_top_ranked_players(df=df_goals, metric='Championship Goals', top_n=25)
# Out:
#                   Player           Team position Championship Season  \
# 286  Aleksandar Mitrović         Fulham      FWD             2021-22
# 235           Ivan Toney      Brentford      FWD             2020-21
# 140          Teemu Pukki        Norwich      FWD             2018-19
# 287      Dominic Solanke    Bournemouth      FWD             2021-22
# 236          Teemu Pukki        Norwich      FWD             2020-21
# 190  Aleksandar Mitrović         Fulham      FWD             2019-20
# 0             Andre Gray        Burnley      FWD             2015-16
# 142          Billy Sharp  Sheffield Utd      FWD             2018-19
# 49          Glenn Murray       Brighton      FWD             2016-17
# 48          Dwight Gayle      Newcastle      FWD             2016-17
# 327       Carlton Morris          Luton      FWD             2022-23
# 1         Abel Hernández           Hull      FWD             2015-16
# 90            Diogo Jota         Wolves      MID             2017-18
# 191      Patrick Bamford          Leeds      FWD             2019-20
# 2          Jordan Rhodes  Middlesbrough      FWD             2015-16
# 288      Brennan Johnson  Nott'm Forest      FWD             2021-22
# 91        Ryan Sessegnon         Fulham      MID             2017-18
# 143     David McGoldrick  Sheffield Utd      FWD             2018-19
# 50     Anthony Knockaert       Brighton      MID             2016-17
# 3              Sam Vokes        Burnley      FWD             2015-16
# 329        Iliman Ndiaye  Sheffield Utd      FWD             2022-23
# 330      Oliver McBurnie  Sheffield Utd      FWD             2022-23
# 238         Ismaïla Sarr        Watford      MID             2020-21
# 52          Matt Ritchie      Newcastle      MID             2016-17
# 51        Elias Kachunga   Huddersfield      MID             2016-17
# 93   Aleksandar Mitrović         Fulham      FWD             2017-18
# 331        Manuel Benson        Burnley      MID             2022-23
#
#      Championship Goals FPL Season  FPL Points  FPL Goals  FPL Assists  Rank
# 286                  43    2022-23       107.0       14.0          2.0   1.0
# 235                  30    2021-22       139.0       12.0          5.0   2.0
# 140                  29    2019-20       139.0       11.0          3.0   3.0
# 287                  29    2022-23       130.0        6.0         10.0   3.0
# 236                  26    2021-22       142.0       11.0          3.0   5.0
# 190                  26    2020-21        63.0        3.0          3.0   5.0
# 0                    25    2016-17       108.0        9.0          3.0   7.0
# 142                  23    2019-20        57.0        3.0          2.0   8.0
# 49                   23    2017-18       111.0       12.0          0.0   8.0
# 48                   23    2017-18        94.0        6.0          3.0   8.0
# 327                  20    2023-24       146.0       11.0          6.0  11.0
# 1                    20    2016-17        72.0        4.0          4.0  11.0
# 90                   17    2018-19       139.0        9.0          8.0  13.0
# 191                  16    2020-21       194.0       17.0         11.0  14.0
# 2                    16    2016-17         8.0        0.0          0.0  14.0
# 288                  16    2022-23       122.0        8.0          5.0  14.0
# 91                   15    2018-19        94.0        2.0          7.0  17.0
# 143                  15    2019-20        65.0        2.0          2.0  17.0
# 50                   15    2017-18        88.0        3.0          1.0  17.0
# 3                    15    2016-17       121.0       10.0          4.0  17.0
# 329                  14    2023-24         0.0        0.0          0.0  21.0
# 330                  13    2023-24        66.0        6.0          3.0  22.0
# 238                  13    2021-22        81.0        5.0          2.0  22.0
# 52                   12    2017-18       116.0        3.0          7.0  24.0
# 51                   12    2017-18        46.0        1.0          1.0  24.0
# 93                   12    2018-19       134.0       11.0          4.0  24.0
# 331                  12    2023-24         8.0        0.0          0.0  24.0

# %%
get_top_ranked_players(df=df_assists, metric='Championship Assists', top_n=25)
# Out:
#                     Player           Team position Championship Season  \
# 285           Harry Wilson         Fulham      MID             2021-22
# 192        Matheus Pereira      West Brom      MID             2019-20
# 96           Barry Douglas         Wolves      DEF             2017-18
# 97          Ivan Cavaleiro         Wolves      MID             2017-18
# 0               Andre Gray        Burnley      FWD             2015-16
# 145        Conor Hourihane    Aston Villa      MID             2018-19
# 144       Emiliano Buendia        Norwich      MID             2018-19
# 98          Junior Hoilett        Cardiff      MID             2017-18
# 335          Iliman Ndiaye  Sheffield Utd      FWD             2022-23
# 286         Philip Billing    Bournemouth      MID             2021-22
# 238             Ivan Toney      Brentford      FWD             2020-21
# 287        Brennan Johnson  Nott'm Forest      FWD             2021-22
# 146             John Fleck  Sheffield Utd      MID             2018-19
# 147            Teemu Pukki        Norwich      FWD             2018-19
# 237           Bryan Mbeumo      Brentford      MID             2020-21
# 194        Pablo Hernández          Leeds      MID             2019-20
# 193          Jack Harrison          Leeds      MID             2019-20
# 149            John McGinn    Aston Villa      MID             2018-19
# 148         Onel Hernández        Norwich      MID             2018-19
# 151         Oliver Norwood  Sheffield Utd      MID             2018-19
# 150       Ahmed Elmohamady    Aston Villa      DEF             2018-19
# 1               Sam Clucas           Hull      MID             2015-16
# 99         Stefan Johansen         Fulham      MID             2017-18
# 54             Tommy Smith   Huddersfield      DEF             2016-17
# 53           Jonjo Shelvey      Newcastle      MID             2016-17
# 52       Anthony Knockaert       Brighton      MID             2016-17
# 288          Ryan Christie    Bournemouth      MID             2021-22
# 289  Bobby De Cordova-Reid         Fulham      MID             2021-22
# 2             David Nugent  Middlesbrough      FWD             2015-16
# 336         Josh Brownhill        Burnley      MID             2022-23
#
#      Championship Assists FPL Season  FPL Points  FPL Goals  FPL Assists  Rank
# 285                    19    2022-23        68.0        2.0          5.0   1.0
# 192                    17    2020-21       153.0       11.0          7.0   2.0
# 96                     14    2018-19         0.0        0.0          0.0   3.0
# 97                     12    2018-19        48.0        3.0          1.0   4.0
# 0                      11    2016-17       108.0        9.0          3.0   5.0
# 145                    11    2019-20        83.0        3.0          5.0   5.0
# 144                    11    2019-20        94.0        1.0          7.0   5.0
# 98                     11    2018-19        82.0        3.0          2.0   5.0
# 335                    11    2023-24         0.0        0.0          0.0   5.0
# 286                    10    2022-23       126.0        7.0          2.0  10.0
# 238                    10    2021-22       139.0       12.0          5.0  10.0
# 287                    10    2022-23       122.0        8.0          5.0  10.0
# 146                    10    2019-20       101.0        5.0          2.0  10.0
# 147                    10    2019-20       139.0       11.0          3.0  10.0
# 237                    10    2021-22       119.0        4.0          7.0  10.0
# 194                     9    2020-21        28.0        0.0          3.0  16.0
# 193                     9    2020-21       160.0        8.0         10.0  16.0
# 149                     9    2019-20        84.0        3.0          3.0  16.0
# 148                     9    2019-20        52.0        1.0          2.0  16.0
# 151                     8    2019-20        98.0        1.0          3.0  20.0
# 150                     8    2019-20        39.0        1.0          1.0  20.0
# 1                       8    2016-17        87.0        3.0          1.0  20.0
# 99                      8    2018-19        11.0        0.0          0.0  20.0
# 54                      8    2017-18        50.0        0.0          1.0  20.0
# 53                      8    2017-18        73.0        1.0          4.0  20.0
# 52                      8    2017-18        88.0        3.0          1.0  20.0
# 288                     8    2022-23        64.0        1.0          2.0  20.0
# 289                     8    2022-23        90.0        4.0          1.0  20.0
# 2                       8    2016-17         4.0        0.0          0.0  20.0
# 336                     8    2023-24        78.0        4.0          2.0  20.0
