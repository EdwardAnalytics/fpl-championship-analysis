# %%
# Change directory to level up to import functions
import os
os.chdir('..')

import warnings

# Suppress all warnings
warnings.filterwarnings('ignore')

# %%
combined_df
# Out:
#               Team   Season  Total Points  GK Points  DEF Points  MID Points  \
# 86           Leeds  2020-21          1691        168         609         630
# 66   Sheffield Utd  2019-20          1594        163         817         315
# 129         Fulham  2022-23          1550        149         430         785
# 48          Wolves  2018-19          1530        126         622         591
# 27       Newcastle  2017-18          1472        143         465         542
# 112      Brentford  2021-22          1467        126         496         692
# 33        Brighton  2017-18          1398        146         412         648
# 14         Burnley  2016-17          1380        154         423         488
# 75     Aston Villa  2019-20          1357        116         434         704
# 54         Cardiff  2018-19          1355        154         437         613
# 16   Middlesbrough  2016-17          1352        138         468         508
# ...
